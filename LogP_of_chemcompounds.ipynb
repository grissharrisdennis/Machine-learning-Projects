# %%
import numpy as np # linear algebra
import pandas as pd
# !pip install rdkit-pypi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 41.0 MB/s eta 0:00:00
# ...

# %%
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-032dc67b-be1f-4024-b604-172b6ca968a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-032dc67b-be1f-4024-b604-172b6ca968a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('logP_dataset.csv',names=['SMILES','logP'])
data.head()
# Out:
#                                         SMILES  logP
# 0                        C[C@H]([C@@H](C)Cl)Cl   2.3
# 1                                    C(C=CBr)N   0.3
# 2                                    CCC(CO)Br   1.3
# 3  [13CH3][13CH2][13CH2][13CH2][13CH2][13CH2]O   2.0
# 4                                      CCCOCCP   0.6
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['logP'].plot(kind='hist', bins=20, title='logP')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('SMILES').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors,Crippen


data['Molecule'] = data['SMILES'].apply(Chem.MolFromSmiles)
data['MolecularWeight'] = data['Molecule'].apply(Descriptors.MolWt)
data['Polar Surface Area']=data['Molecule'].apply(Crippen.MolLogP)
data.head()
# Out:
#                                         SMILES  logP  \
# 0                        C[C@H]([C@@H](C)Cl)Cl   2.3
# 1                                    C(C=CBr)N   0.3
# 2                                    CCC(CO)Br   1.3
# 3  [13CH3][13CH2][13CH2][13CH2][13CH2][13CH2]O   2.0
# 4                                      CCCOCCP   0.6
#
#                                            Molecule  MolecularWeight  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x784f020bb760>       127.014000
# 1  <rdkit.Chem.rdchem.Mol object at 0x784f020bb990>       135.992000
# 2  <rdkit.Chem.rdchem.Mol object at 0x784f020bba00>       153.019000
# 3  <rdkit.Chem.rdchem.Mol object at 0x784f020bb680>       108.131129
# 4  <rdkit.Chem.rdchem.Mol object at 0x784f020bb610>       120.132000
#
#    Polar Surface Area
# 0              2.2410
# 1              0.8537
# 2              1.1522
# 3              1.5590
# 4              1.2881
